# %%
#importing the pandas library
import pandas as pd

# %%
#reading the file
df = pd.read_csv('../data-companywise/ICFC.csv')
df
# Out:
#      published_date   open   high    low  close  per_change  traded_quantity  \
# 0        2011-05-16  165.0  165.0  162.0  162.0         NaN            150.0
# 1        2011-05-18  162.0  160.0  160.0  160.0       -1.23             30.0
# 2        2011-05-19  160.0  157.0  157.0  157.0       -1.88             20.0
# 3        2011-05-23  157.0  154.0  150.0  150.0       -4.46            306.0
# 4        2011-05-24  150.0  147.0  147.0  147.0       -2.00            100.0
# ...             ...    ...    ...    ...    ...         ...              ...
# 3001     2026-01-14  642.2  667.0  640.1  660.0        2.68          82524.0
# 3002     2026-01-18  671.9  700.1  661.1  696.0        5.45         141531.0
# 3003     2026-01-20  709.8  715.0  695.0  698.4        0.34         147123.0
# 3004     2026-01-21  699.0  700.0  680.0  691.0       -1.06          52858.0
# 3005     2026-01-22  690.0  703.0  680.2  695.0        0.58         103245.0
#
#       traded_amount
# 0           24480.0
# 1            4800.0
# 2            3140.0
# 3           46784.0
# 4           14700.0
# ...             ...
# 3001     54550295.3
# 3002     97297756.5
# 3003    103677206.3
# 3004     36413067.4
# 3005     71345952.4
#
# [3006 rows x 8 columns]

# %%
# Rename specific columns to the "Perfect Schema"
df = df.rename(columns={
    'published_date': 'date',
    'traded_quantity': 'volume',
    'traded_amount': 'turnover',
    'per_change': 'price_change_pct'
})

# %%
#year column created
df['date'] = pd.to_datetime(df['date'])   # convert first
df['year'] = df['date'].dt.year

# %%
df
# Out:
#            date   open   high    low  close  price_change_pct    volume  \
# 0    2011-05-16  165.0  165.0  162.0  162.0               NaN     150.0
# 1    2011-05-18  162.0  160.0  160.0  160.0             -1.23      30.0
# 2    2011-05-19  160.0  157.0  157.0  157.0             -1.88      20.0
# 3    2011-05-23  157.0  154.0  150.0  150.0             -4.46     306.0
# 4    2011-05-24  150.0  147.0  147.0  147.0             -2.00     100.0
# ...         ...    ...    ...    ...    ...               ...       ...
# 3001 2026-01-14  642.2  667.0  640.1  660.0              2.68   82524.0
# 3002 2026-01-18  671.9  700.1  661.1  696.0              5.45  141531.0
# 3003 2026-01-20  709.8  715.0  695.0  698.4              0.34  147123.0
# 3004 2026-01-21  699.0  700.0  680.0  691.0             -1.06   52858.0
# 3005 2026-01-22  690.0  703.0  680.2  695.0              0.58  103245.0
#
#          turnover  year
# 0         24480.0  2011
# 1          4800.0  2011
# 2          3140.0  2011
# 3         46784.0  2011
# 4         14700.0  2011
# ...           ...   ...
# 3001   54550295.3  2026
# 3002   97297756.5  2026
# 3003  103677206.3  2026
# 3004   36413067.4  2026
# 3005   71345952.4  2026
#
# [3006 rows x 9 columns]

# %%
#filtering the data from 2022
df['date'] = pd.to_datetime(df['date'])
df=df[df['date'].dt.year >= 2022].copy()

# %%
df
# Out:
#            date   open   high    low  close  price_change_pct    volume  \
# 2065 2022-01-02  585.0  593.0  580.0  589.0              0.63   35465.0
# 2066 2022-01-03  599.0  607.9  587.1  595.0              1.02   65710.0
# 2067 2022-01-04  595.1  609.0  585.0  607.0              2.02   61815.0
# 2068 2022-01-05  619.0  629.0  601.0  605.2             -0.30   86845.0
# 2069 2022-01-06  597.1  617.0  595.0  614.0              1.45   45566.0
# ...         ...    ...    ...    ...    ...               ...       ...
# 3001 2026-01-14  642.2  667.0  640.1  660.0              2.68   82524.0
# 3002 2026-01-18  671.9  700.1  661.1  696.0              5.45  141531.0
# 3003 2026-01-20  709.8  715.0  695.0  698.4              0.34  147123.0
# 3004 2026-01-21  699.0  700.0  680.0  691.0             -1.06   52858.0
# 3005 2026-01-22  690.0  703.0  680.2  695.0              0.58  103245.0
#
#          turnover  year
# 2065   20836762.7  2022
# 2066   39435972.3  2022
# 2067   37200691.4  2022
# 2068   53436314.7  2022
# 2069   27864070.9  2022
# ...           ...   ...
# 3001   54550295.3  2026
# 3002   97297756.5  2026
# 3003  103677206.3  2026
# 3004   36413067.4  2026
# 3005   71345952.4  2026
#
# [941 rows x 9 columns]

# %%
#resetting index
df.reset_index(drop= True, inplace = True)
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2022-01-02  585.0  593.0  580.0  589.0              0.63   35465.0
# 1   2022-01-03  599.0  607.9  587.1  595.0              1.02   65710.0
# 2   2022-01-04  595.1  609.0  585.0  607.0              2.02   61815.0
# 3   2022-01-05  619.0  629.0  601.0  605.2             -0.30   86845.0
# 4   2022-01-06  597.1  617.0  595.0  614.0              1.45   45566.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 936 2026-01-14  642.2  667.0  640.1  660.0              2.68   82524.0
# 937 2026-01-18  671.9  700.1  661.1  696.0              5.45  141531.0
# 938 2026-01-20  709.8  715.0  695.0  698.4              0.34  147123.0
# 939 2026-01-21  699.0  700.0  680.0  691.0             -1.06   52858.0
# 940 2026-01-22  690.0  703.0  680.2  695.0              0.58  103245.0
#
#         turnover  year
# 0     20836762.7  2022
# 1     39435972.3  2022
# 2     37200691.4  2022
# 3     53436314.7  2022
# 4     27864070.9  2022
# ..           ...   ...
# 936   54550295.3  2026
# 937   97297756.5  2026
# 938  103677206.3  2026
# 939   36413067.4  2026
# 940   71345952.4  2026
#
# [941 rows x 9 columns]

# %%
fundamental_data = {
    'year': [2022, 2023, 2024, 2025], 
    'eps': [12.91, 13.97, 10.03, 22.63], 
    'pe-ratio': [31.50, 28.10, 76.70, 26.60], 
    'roe': [9.45, 9.60, 6.41, 12.92],   
    'dividend': [10.00, 6.50, 5.26, 15.79]
}
df_fundamental = pd.DataFrame(fundamental_data)
df_fundamental
# Out:
#    year    eps  pe-ratio    roe  dividend
# 0  2022  12.91      31.5   9.45     10.00
# 1  2023  13.97      28.1   9.60      6.50
# 2  2024  10.03      76.7   6.41      5.26
# 3  2025  22.63      26.6  12.92     15.79

# %%
# merging
df = pd.merge(df, df_fundamental, on='year',how= 'left')
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2022-01-02  585.0  593.0  580.0  589.0              0.63   35465.0
# 1   2022-01-03  599.0  607.9  587.1  595.0              1.02   65710.0
# 2   2022-01-04  595.1  609.0  585.0  607.0              2.02   61815.0
# 3   2022-01-05  619.0  629.0  601.0  605.2             -0.30   86845.0
# 4   2022-01-06  597.1  617.0  595.0  614.0              1.45   45566.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 936 2026-01-14  642.2  667.0  640.1  660.0              2.68   82524.0
# 937 2026-01-18  671.9  700.1  661.1  696.0              5.45  141531.0
# 938 2026-01-20  709.8  715.0  695.0  698.4              0.34  147123.0
# 939 2026-01-21  699.0  700.0  680.0  691.0             -1.06   52858.0
# 940 2026-01-22  690.0  703.0  680.2  695.0              0.58  103245.0
#
#         turnover  year    eps  pe-ratio   roe  dividend
# 0     20836762.7  2022  12.91      31.5  9.45      10.0
# 1     39435972.3  2022  12.91      31.5  9.45      10.0
# 2     37200691.4  2022  12.91      31.5  9.45      10.0
# 3     53436314.7  2022  12.91      31.5  9.45      10.0
# 4     27864070.9  2022  12.91      31.5  9.45      10.0
# ..           ...   ...    ...       ...   ...       ...
# 936   54550295.3  2026    NaN       NaN   NaN       NaN
# 937   97297756.5  2026    NaN       NaN   NaN       NaN
# 938  103677206.3  2026    NaN       NaN   NaN       NaN
# 939   36413067.4  2026    NaN       NaN   NaN       NaN
# 940   71345952.4  2026    NaN       NaN   NaN       NaN
#
# [941 rows x 13 columns]

# %%
df = df.copy()
df.to_csv('../data-companywise/ICFC.csv', index = False)
