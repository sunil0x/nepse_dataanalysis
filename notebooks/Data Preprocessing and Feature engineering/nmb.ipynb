# %%
#importing the pandas library
import pandas as pd

# %%
#reading the file
df = pd.read_csv('../data-companywise/raw_data/NMB.csv')
df
# Out:
#      published_date   open   high    low  close  per_change  traded_quantity  \
# 0        2011-03-29  228.0  233.0  225.0  232.0         NaN           1017.0
# 1        2011-03-30  232.0  235.0  228.0  235.0        1.29            250.0
# 2        2011-03-31  235.0  231.0  231.0  231.0       -1.70           1000.0
# 3        2011-04-04  231.0  227.0  225.0  226.0       -2.16            190.0
# 4        2011-04-06  226.0  225.0  225.0  225.0       -0.44            100.0
# ...             ...    ...    ...    ...    ...         ...              ...
# 3025     2026-02-24  235.0  235.0  232.4  234.8        0.77          11140.0
# 3026     2026-02-25  236.0  236.0  233.1  234.5       -0.13          22338.0
# 3027     2026-02-26  239.1  239.1  234.0  238.5        1.71          40152.0
# 3028     2026-03-01  234.2  238.8  234.1  238.8        0.13          39746.0
# 3029     2026-03-03  243.5  243.5  235.4  241.9        1.30          31533.0
#
#       traded_amount  status
# ...

# %%
df.drop(columns = 'status', inplace = True)
df
# Out:
#      published_date   open   high    low  close  per_change  traded_quantity  \
# 0        2011-03-29  228.0  233.0  225.0  232.0         NaN           1017.0
# 1        2011-03-30  232.0  235.0  228.0  235.0        1.29            250.0
# 2        2011-03-31  235.0  231.0  231.0  231.0       -1.70           1000.0
# 3        2011-04-04  231.0  227.0  225.0  226.0       -2.16            190.0
# 4        2011-04-06  226.0  225.0  225.0  225.0       -0.44            100.0
# ...             ...    ...    ...    ...    ...         ...              ...
# 3025     2026-02-24  235.0  235.0  232.4  234.8        0.77          11140.0
# 3026     2026-02-25  236.0  236.0  233.1  234.5       -0.13          22338.0
# 3027     2026-02-26  239.1  239.1  234.0  238.5        1.71          40152.0
# 3028     2026-03-01  234.2  238.8  234.1  238.8        0.13          39746.0
# 3029     2026-03-03  243.5  243.5  235.4  241.9        1.30          31533.0
#
#       traded_amount
# 0          232392.0
# ...

# %%
# Rename specific columns to the "Perfect Schema"
df = df.rename(columns={
    'published_date': 'date',
    'traded_quantity': 'volume',
    'traded_amount': 'turnover',
    'per_change': 'price_change_pct'
})

# %%
df.drop(columns = 'status', inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.drop(columns = 'status', inplace = True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
# ...

# %%
#year column created
df['date'] = pd.to_datetime(df['date'])   # convert first
df['year'] = df['date'].dt.year

# %%
df

# %%
#filtering the data from 2022
df['date'] = pd.to_datetime(df['date'])
df = df[df['date'].dt.year > 2022].copy()

# %%
df

# %%
#resetting index
df.reset_index(drop= True, inplace = True)
df

# %%
fundamental_data = {
    'year': [2022, 2023, 2024, 2025], # Corresponding to FY 78/79, 79/80, 80/81, 81/82
    'eps': [18.79, 13.06, 12.12, 17.87],
    'pe-ratio': [16.23, 15.50, 16.00, 13.50],
    'roe': [13.32, 8.66, 8.12, 10.41],
    'dividend': [8.25, 0.00, 0.00, 10.00]}
df_fundamental = pd.DataFrame(fundamental_data)
df_fundamental

# %%
# merging
df = pd.merge(df, df_fundamental, on='year',how= 'left')
df

# %%
df = df.copy()
df.to_csv('../data-companywise/processed_data/NMB.csv', index = False)
