# %%
#importing the pandas library
import pandas as pd

# %%
#reading the file
df = pd.read_csv('../../data-companywise/raw_data/SAHAS.csv')
df
# Out:
#     published_date   open   high    low  close  per_change  traded_quantity  \
# 0       2021-12-08  622.3  634.0  594.0  595.0       -6.30          31289.0
# 1       2021-12-09  595.0  619.0  572.0  581.0       -2.35          44125.0
# 2       2021-12-12  570.1  584.6  545.0  545.0       -6.20          39265.0
# 3       2021-12-13  535.0  542.0  500.0  513.0       -5.87          38196.0
# 4       2021-12-14  505.0  564.0  505.0  563.0        9.75          14615.0
# ..             ...    ...    ...    ...    ...         ...              ...
# 975     2026-02-24  560.0  562.0  552.1  557.0        0.54         137303.0
# 976     2026-02-25  548.1  562.7  548.1  562.7        1.02          80571.0
# 977     2026-02-26  572.0  572.0  556.2  566.0        0.59          52864.0
# 978     2026-03-01  567.0  581.0  555.0  579.0        2.30         231003.0
# 979     2026-03-03  585.0  594.8  577.0  589.0        1.73         234606.0
#
#      traded_amount  status
# 0       18929146.0      -1
# 1       25700423.0      -1
# 2       21998112.2      -1
# 3       19595979.6      -1
# 4        7901219.0       1
# ..             ...     ...
# 975     76550248.3      -1
# 976     45087176.5       1
# 977     29781694.9      -1
# 978    132538645.9       1
# 979    138095977.7       1
#
# [980 rows x 9 columns]

# %%
df.drop(columns = 'status', inplace = True)
df
# Out:
#     published_date   open   high    low  close  per_change  traded_quantity  \
# 0       2021-12-08  622.3  634.0  594.0  595.0       -6.30          31289.0
# 1       2021-12-09  595.0  619.0  572.0  581.0       -2.35          44125.0
# 2       2021-12-12  570.1  584.6  545.0  545.0       -6.20          39265.0
# 3       2021-12-13  535.0  542.0  500.0  513.0       -5.87          38196.0
# 4       2021-12-14  505.0  564.0  505.0  563.0        9.75          14615.0
# ..             ...    ...    ...    ...    ...         ...              ...
# 975     2026-02-24  560.0  562.0  552.1  557.0        0.54         137303.0
# 976     2026-02-25  548.1  562.7  548.1  562.7        1.02          80571.0
# 977     2026-02-26  572.0  572.0  556.2  566.0        0.59          52864.0
# 978     2026-03-01  567.0  581.0  555.0  579.0        2.30         231003.0
# 979     2026-03-03  585.0  594.8  577.0  589.0        1.73         234606.0
#
#      traded_amount
# 0       18929146.0
# 1       25700423.0
# 2       21998112.2
# 3       19595979.6
# 4        7901219.0
# ..             ...
# 975     76550248.3
# 976     45087176.5
# 977     29781694.9
# 978    132538645.9
# 979    138095977.7
#
# [980 rows x 8 columns]

# %%
# Rename specific columns to the "Perfect Schema"
df = df.rename(columns={
    'published_date': 'date',
    'traded_quantity': 'volume',
    'traded_amount': 'turnover',
    'per_change': 'price_change_pct'
})

# %%
df
# Out:
#            date   open   high    low  close  price_change_pct    volume  \
# 0    2021-12-08  622.3  634.0  594.0  595.0             -6.30   31289.0
# 1    2021-12-09  595.0  619.0  572.0  581.0             -2.35   44125.0
# 2    2021-12-12  570.1  584.6  545.0  545.0             -6.20   39265.0
# 3    2021-12-13  535.0  542.0  500.0  513.0             -5.87   38196.0
# 4    2021-12-14  505.0  564.0  505.0  563.0              9.75   14615.0
# ..          ...    ...    ...    ...    ...               ...       ...
# 975  2026-02-24  560.0  562.0  552.1  557.0              0.54  137303.0
# 976  2026-02-25  548.1  562.7  548.1  562.7              1.02   80571.0
# 977  2026-02-26  572.0  572.0  556.2  566.0              0.59   52864.0
# 978  2026-03-01  567.0  581.0  555.0  579.0              2.30  231003.0
# 979  2026-03-03  585.0  594.8  577.0  589.0              1.73  234606.0
#
#         turnover
# 0     18929146.0
# 1     25700423.0
# 2     21998112.2
# 3     19595979.6
# 4      7901219.0
# ..           ...
# 975   76550248.3
# 976   45087176.5
# 977   29781694.9
# 978  132538645.9
# 979  138095977.7
#
# [980 rows x 8 columns]

# %%
#year column created
df['date'] = pd.to_datetime(df['date'])   # convert first
df['year'] = df['date'].dt.year

# %%
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2021-12-08  622.3  634.0  594.0  595.0             -6.30   31289.0
# 1   2021-12-09  595.0  619.0  572.0  581.0             -2.35   44125.0
# 2   2021-12-12  570.1  584.6  545.0  545.0             -6.20   39265.0
# 3   2021-12-13  535.0  542.0  500.0  513.0             -5.87   38196.0
# 4   2021-12-14  505.0  564.0  505.0  563.0              9.75   14615.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 975 2026-02-24  560.0  562.0  552.1  557.0              0.54  137303.0
# 976 2026-02-25  548.1  562.7  548.1  562.7              1.02   80571.0
# 977 2026-02-26  572.0  572.0  556.2  566.0              0.59   52864.0
# 978 2026-03-01  567.0  581.0  555.0  579.0              2.30  231003.0
# 979 2026-03-03  585.0  594.8  577.0  589.0              1.73  234606.0
#
#         turnover  year
# 0     18929146.0  2021
# 1     25700423.0  2021
# 2     21998112.2  2021
# 3     19595979.6  2021
# 4      7901219.0  2021
# ..           ...   ...
# 975   76550248.3  2026
# 976   45087176.5  2026
# 977   29781694.9  2026
# 978  132538645.9  2026
# 979  138095977.7  2026
#
# [980 rows x 9 columns]

# %%
#filtering the data from 2022
df['date'] = pd.to_datetime(df['date'])
df=df[df['date'].dt.year >= 2022].copy()

# %%
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 15  2022-01-02  540.0  565.0  534.2  549.0              0.73   15457.0
# 16  2022-01-03  545.0  559.0  539.0  544.0             -0.91   46593.0
# 17  2022-01-04  541.0  568.0  536.0  566.0              4.04   27443.0
# 18  2022-01-05  565.0  608.0  560.6  580.0              2.47   69522.0
# 19  2022-01-06  570.0  608.0  569.0  607.0              4.66   67178.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 975 2026-02-24  560.0  562.0  552.1  557.0              0.54  137303.0
# 976 2026-02-25  548.1  562.7  548.1  562.7              1.02   80571.0
# 977 2026-02-26  572.0  572.0  556.2  566.0              0.59   52864.0
# 978 2026-03-01  567.0  581.0  555.0  579.0              2.30  231003.0
# 979 2026-03-03  585.0  594.8  577.0  589.0              1.73  234606.0
#
#         turnover  year
# 15     8417646.9  2022
# 16    25564459.0  2022
# 17    15226271.3  2022
# 18    40744392.3  2022
# 19    40122758.1  2022
# ..           ...   ...
# 975   76550248.3  2026
# 976   45087176.5  2026
# 977   29781694.9  2026
# 978  132538645.9  2026
# 979  138095977.7  2026
#
# [965 rows x 9 columns]

# %%
#resetting index
df.reset_index(drop= True, inplace = True)
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2022-01-02  540.0  565.0  534.2  549.0              0.73   15457.0
# 1   2022-01-03  545.0  559.0  539.0  544.0             -0.91   46593.0
# 2   2022-01-04  541.0  568.0  536.0  566.0              4.04   27443.0
# 3   2022-01-05  565.0  608.0  560.6  580.0              2.47   69522.0
# 4   2022-01-06  570.0  608.0  569.0  607.0              4.66   67178.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 960 2026-02-24  560.0  562.0  552.1  557.0              0.54  137303.0
# 961 2026-02-25  548.1  562.7  548.1  562.7              1.02   80571.0
# 962 2026-02-26  572.0  572.0  556.2  566.0              0.59   52864.0
# 963 2026-03-01  567.0  581.0  555.0  579.0              2.30  231003.0
# 964 2026-03-03  585.0  594.8  577.0  589.0              1.73  234606.0
#
#         turnover  year
# 0      8417646.9  2022
# 1     25564459.0  2022
# 2     15226271.3  2022
# 3     40744392.3  2022
# 4     40122758.1  2022
# ..           ...   ...
# 960   76550248.3  2026
# 961   45087176.5  2026
# 962   29781694.9  2026
# 963  132538645.9  2026
# 964  138095977.7  2026
#
# [965 rows x 9 columns]

# %%
fundamental_data = {
    'year': [2022, 2023, 2024, 2025], # Corresponding to FY 78/79, 79/80, 80/81, 81/82
    'eps': [0.18, 2.94, 9.10, 23.88],
    'pe-ratio': [3245.0, 185.20, 68.50, 28.50],
    'roe': [0.12, 1.84, 6.94, 13.63],
    'dividend': [0.00, 0.00, 8.42, 22.11],
    'net-margin': [16.99, 26.36, 34.03, 40.04],
    'pb-ratio': [2.80, 3.20, 3.70, 3.40],
    'debt-equity': [2.10, 1.85, 1.60, 1.45]
}
df_fundamental = pd.DataFrame(fundamental_data)
df_fundamental
# Out:
#    year    eps  pe-ratio    roe  dividend
# 0  2022   0.18    3245.0   0.12      0.00
# 1  2023   2.94     185.2   1.84      0.00
# 2  2024   9.10      68.5   6.94      8.42
# 3  2025  23.88      28.5  13.63     22.11

# %%
# merging
df = pd.merge(df, df_fundamental, on='year',how= 'left')
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2022-01-02  540.0  565.0  534.2  549.0              0.73   15457.0
# 1   2022-01-03  545.0  559.0  539.0  544.0             -0.91   46593.0
# 2   2022-01-04  541.0  568.0  536.0  566.0              4.04   27443.0
# 3   2022-01-05  565.0  608.0  560.6  580.0              2.47   69522.0
# 4   2022-01-06  570.0  608.0  569.0  607.0              4.66   67178.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 960 2026-02-24  560.0  562.0  552.1  557.0              0.54  137303.0
# 961 2026-02-25  548.1  562.7  548.1  562.7              1.02   80571.0
# 962 2026-02-26  572.0  572.0  556.2  566.0              0.59   52864.0
# 963 2026-03-01  567.0  581.0  555.0  579.0              2.30  231003.0
# 964 2026-03-03  585.0  594.8  577.0  589.0              1.73  234606.0
#
#         turnover  year   eps  pe-ratio   roe  dividend
# 0      8417646.9  2022  0.18    3245.0  0.12       0.0
# 1     25564459.0  2022  0.18    3245.0  0.12       0.0
# 2     15226271.3  2022  0.18    3245.0  0.12       0.0
# 3     40744392.3  2022  0.18    3245.0  0.12       0.0
# 4     40122758.1  2022  0.18    3245.0  0.12       0.0
# ..           ...   ...   ...       ...   ...       ...
# 960   76550248.3  2026   NaN       NaN   NaN       NaN
# 961   45087176.5  2026   NaN       NaN   NaN       NaN
# 962   29781694.9  2026   NaN       NaN   NaN       NaN
# 963  132538645.9  2026   NaN       NaN   NaN       NaN
# 964  138095977.7  2026   NaN       NaN   NaN       NaN
#
# [965 rows x 13 columns]

# %%
df = df.copy()
df.to_csv('../../data-companywise/processed_data/SAHAS.csv', index = False)

# %%
#PROBLEM SOLUTION:
# git config --global core.autocrlf true
