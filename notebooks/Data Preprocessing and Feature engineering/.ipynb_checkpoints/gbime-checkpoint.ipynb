# %%
#importing the pandas library
import pandas as pd

# %%
#reading the file
df = pd.read_csv('../../data-companywise/raw_data/GBIME.csv')
df
# Out:
#      published_date   open   high    low  close  per_change  traded_quantity  \
# 0         9/26/2012  248.0  249.0  244.0  247.0         NaN             7227
# 1         9/30/2012  245.0  247.0  238.0  244.0       -1.21             7236
# 2         10/1/2012  244.0  245.0  240.0  243.0       -0.41             5064
# 3         10/1/2012  244.0  245.0  240.0  243.0        0.00             5064
# 4         10/2/2012  243.0  248.0  242.0  248.0        2.06             2854
# ...             ...    ...    ...    ...    ...         ...              ...
# 2635       3/3/2026  232.5  232.5  221.5  231.0        1.32           118156
# 2636       3/9/2026  235.6  245.1  235.6  250.0        8.23             2979
# 2637      3/10/2026  254.0  255.0  240.1  246.0       -1.76           462000
# 2638      3/11/2026  250.0  250.0  239.5  240.0       -2.40           125000
# 2639      3/12/2026  244.0  248.0  236.0  244.0        1.92           274000
#
#       traded_amount  status
# 0         1771727.0       0
# 1         1747500.0       0
# 2         1229940.0       0
# 3         1229940.0       0
# 4          703587.0       0
# ...             ...     ...
# 2635     27244851.3      -1
# 2636       711000.0       1
# 2637    113400000.0      -1
# 2638     30300000.0      -1
# 2639     66700000.0       1
#
# [2640 rows x 9 columns]

# %%
df.drop(columns = 'status', inplace = True)
df

# %%
# Rename specific columns to the "Perfect Schema"
df = df.rename(columns={
    'published_date': 'date',
    'traded_quantity': 'volume',
    'traded_amount': 'turnover',
    'per_change': 'price_change_pct'
})

# %%
df

# %%
#year column created
df['date'] = pd.to_datetime(df['date'])   # convert first
df['year'] = df['date'].dt.year

# %%
df

# %%
#filtering the data from 2022
df['date'] = pd.to_datetime(df['date'])
df=df[df['date'].dt.year >= 2022].copy()

# %%
df

# %%
#resetting index
df.reset_index(drop= True, inplace = True)
df

# %%
fundamental_data = {
    'year': [2022, 2023, 2024, 2025], # Corresponding to FY 78/79, 79/80, 80/81, 81/82
    'eps': [21.72, 16.04, 18.25, 21.10],
    'pe-ratio': [12.01, 11.21, 14.54, 15.95],
    'roe': [13.57, 11.41, 10.20, 9.62],
    'dividend': [13.60, 9.00, 5.50, 8.00]
}
df_fundamental = pd.DataFrame(fundamental_data)
df_fundamental

# %%
# merging
df = pd.merge(df, df_fundamental, on='year',how= 'left')
df

# %%
df = df.copy()
df.to_csv('../data-companywise/processed_data/GBIME.csv', index = False)
