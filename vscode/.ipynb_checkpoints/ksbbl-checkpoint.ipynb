# %%
#importing the pandas library
import pandas as pd

# %%
#reading the file
df = pd.read_csv('../data-companywise/KSBBL.csv')
df
# Out:
#      published_date   open   high    low  close  per_change  traded_quantity  \
# 0        2017-09-26  216.0  218.0  214.0  218.0         NaN          10633.0
# 1        2017-10-03  218.0  218.0  213.0  217.0       -0.46           2751.0
# 2        2017-10-04  217.0  222.0  215.0  215.0       -0.92           6871.0
# 3        2017-10-08  215.0  212.0  203.0  211.0       -1.86          12008.0
# 4        2017-10-09  211.0  212.0  204.0  206.0       -2.37           7255.0
# ...             ...    ...    ...    ...    ...         ...              ...
# 1901     2026-01-14  455.0  457.0  450.3  453.0        0.22          32716.0
# 1902     2026-01-18  450.7  472.0  450.0  472.0        4.19          56819.0
# 1903     2026-01-20  473.5  487.0  472.0  484.5        2.65         152071.0
# 1904     2026-01-21  484.0  488.0  475.2  476.0       -1.75          79601.0
# 1905     2026-01-22  475.0  480.0  469.0  472.9       -0.65          40338.0
#
#       traded_amount
# 0         2293346.0
# 1          590465.0
# 2         1497538.0
# 3         2473364.0
# 4         1502034.0
# ...             ...
# 1901     14814699.2
# 1902     26336383.3
# 1903     72894076.5
# 1904     38193566.9
# 1905     19029212.7
#
# [1906 rows x 8 columns]

# %%
# Rename specific columns to the "Perfect Schema"
df = df.rename(columns={
    'published_date': 'date',
    'traded_quantity': 'volume',
    'traded_amount': 'turnover',
    'per_change': 'price_change_pct'
})

# %%
df['date'] = pd.to_datetime(df['date'])   # convert first
df['year'] = df['date'].dt.year

# %%
#filtering the data from 2022
df['date'] = pd.to_datetime(df['date'])
df=df[df['date'].dt.year >= 2022].copy()

# %%
df
# Out:
#            date   open   high    low  close  price_change_pct    volume  \
# 965  2022-01-02  440.0  450.8  430.1  448.0              2.99   44696.0
# 966  2022-01-03  456.9  469.0  449.0  459.0              2.46   57667.0
# 967  2022-01-04  467.9  491.6  452.1  489.0              6.54  102186.0
# 968  2022-01-05  495.0  504.0  474.0  474.0             -3.07   84716.0
# 969  2022-01-06  474.0  491.6  466.0  486.0              2.53   84786.0
# ...         ...    ...    ...    ...    ...               ...       ...
# 1901 2026-01-14  455.0  457.0  450.3  453.0              0.22   32716.0
# 1902 2026-01-18  450.7  472.0  450.0  472.0              4.19   56819.0
# 1903 2026-01-20  473.5  487.0  472.0  484.5              2.65  152071.0
# 1904 2026-01-21  484.0  488.0  475.2  476.0             -1.75   79601.0
# 1905 2026-01-22  475.0  480.0  469.0  472.9             -0.65   40338.0
#
#         turnover  year
# 965   19810900.2  2022
# 966   26522386.3  2022
# 967   48641547.6  2022
# 968   41381457.5  2022
# 969   40726679.0  2022
# ...          ...   ...
# 1901  14814699.2  2026
# 1902  26336383.3  2026
# 1903  72894076.5  2026
# 1904  38193566.9  2026
# 1905  19029212.7  2026
#
# [941 rows x 9 columns]

# %%
#resetting index
df.reset_index(drop= True, inplace = True)
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2022-01-02  440.0  450.8  430.1  448.0              2.99   44696.0
# 1   2022-01-03  456.9  469.0  449.0  459.0              2.46   57667.0
# 2   2022-01-04  467.9  491.6  452.1  489.0              6.54  102186.0
# 3   2022-01-05  495.0  504.0  474.0  474.0             -3.07   84716.0
# 4   2022-01-06  474.0  491.6  466.0  486.0              2.53   84786.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 936 2026-01-14  455.0  457.0  450.3  453.0              0.22   32716.0
# 937 2026-01-18  450.7  472.0  450.0  472.0              4.19   56819.0
# 938 2026-01-20  473.5  487.0  472.0  484.5              2.65  152071.0
# 939 2026-01-21  484.0  488.0  475.2  476.0             -1.75   79601.0
# 940 2026-01-22  475.0  480.0  469.0  472.9             -0.65   40338.0
#
#        turnover  year
# 0    19810900.2  2022
# 1    26522386.3  2022
# 2    48641547.6  2022
# 3    41381457.5  2022
# 4    40726679.0  2022
# ..          ...   ...
# 936  14814699.2  2026
# 937  26336383.3  2026
# 938  72894076.5  2026
# 939  38193566.9  2026
# 940  19029212.7  2026
#
# [941 rows x 9 columns]

# %%
fundamental_data = {
    'year': [2022, 2023, 2024, 2025],
    'eps': [18.38, 11.01, 16.48, 20.43],  
    'pe-ratio': [18.50, 22.10, 24.12, 22.17], 
    'roe': [11.18, 7.63, 11.10, 12.57], 
    'dividend': [0.00, 4.63, 12.00, 15.79] 
}
df_fundamental = pd.DataFrame(fundamental_data)
df_fundamental
# Out:
#    year    eps  pe-ratio    roe  dividend
# 0  2022  18.38     18.50  11.18      0.00
# 1  2023  11.01     22.10   7.63      4.63
# 2  2024  16.48     24.12  11.10     12.00
# 3  2025  20.43     22.17  12.57     15.79

# %%
# #merging
df = pd.merge(df, df_fundamental, on='year',how= 'left')
df
# Out:
#           date   open   high    low  close  price_change_pct    volume  \
# 0   2022-01-02  440.0  450.8  430.1  448.0              2.99   44696.0
# 1   2022-01-03  456.9  469.0  449.0  459.0              2.46   57667.0
# 2   2022-01-04  467.9  491.6  452.1  489.0              6.54  102186.0
# 3   2022-01-05  495.0  504.0  474.0  474.0             -3.07   84716.0
# 4   2022-01-06  474.0  491.6  466.0  486.0              2.53   84786.0
# ..         ...    ...    ...    ...    ...               ...       ...
# 936 2026-01-14  455.0  457.0  450.3  453.0              0.22   32716.0
# 937 2026-01-18  450.7  472.0  450.0  472.0              4.19   56819.0
# 938 2026-01-20  473.5  487.0  472.0  484.5              2.65  152071.0
# 939 2026-01-21  484.0  488.0  475.2  476.0             -1.75   79601.0
# 940 2026-01-22  475.0  480.0  469.0  472.9             -0.65   40338.0
#
#        turnover  year    eps  pe-ratio    roe  dividend
# 0    19810900.2  2022  18.38      18.5  11.18       0.0
# 1    26522386.3  2022  18.38      18.5  11.18       0.0
# 2    48641547.6  2022  18.38      18.5  11.18       0.0
# 3    41381457.5  2022  18.38      18.5  11.18       0.0
# 4    40726679.0  2022  18.38      18.5  11.18       0.0
# ..          ...   ...    ...       ...    ...       ...
# 936  14814699.2  2026    NaN       NaN    NaN       NaN
# 937  26336383.3  2026    NaN       NaN    NaN       NaN
# 938  72894076.5  2026    NaN       NaN    NaN       NaN
# 939  38193566.9  2026    NaN       NaN    NaN       NaN
# 940  19029212.7  2026    NaN       NaN    NaN       NaN
#
# [941 rows x 13 columns]

# %%
df = df.copy()
df.to_csv('../data-companywise/KSBBL.csv', index = False)
